# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %% [markdown]
# # Part 1: Prepare the Data

# %%
# 1 Read myopia.csv into Pandas DataFrame
file_path = Path('myopia.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
df["MYOPIC"].nunique()
# Out:
# 2

# %%
labels = df['MYOPIC']
labels.value_counts().nunique()
# Out:
# 2

# %%
# Get shape (number of columns and rows) of DataFrame
df.shape
# Out:
# (618, 15)

# %%
# Get column names
df.columns
# Out:
# Index(['AGE', 'SPHEQ', 'AL', 'ACD', 'LT', 'VCD', 'SPORTHR', 'READHR', 'COMPHR',
#        'STUDYHR', 'TVHR', 'DIOPTERHR', 'MOMMY', 'DADMY', 'MYOPIC'],
#       dtype='object')

# %%
# Find out if there are missing/null values
df.isnull().sum()
# Out:
# AGE          0
# SPHEQ        0
# AL           0
# ACD          0
# LT           0
# VCD          0
# SPORTHR      0
# READHR       0
# COMPHR       0
# STUDYHR      0
# TVHR         0
# DIOPTERHR    0
# MOMMY        0
# DADMY        0
# MYOPIC       0
# dtype: int64

# %%
# Find out if there are duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
# Statistical summary
df.describe()
# Out:
#               AGE       SPHEQ          AL         ACD          LT         VCD  \
# count  618.000000  618.000000  618.000000  618.000000  618.000000  618.000000
# mean     6.299353    0.801010   22.496780    3.578629    3.541453   15.376780
# std      0.712950    0.625918    0.680141    0.230394    0.154519    0.664183
# min      5.000000   -0.699000   19.900000    2.772000    2.960000   13.380000
# 25%      6.000000    0.456250   22.040001    3.424000    3.436000   14.930000
# 50%      6.000000    0.729000   22.464999    3.585000    3.542000   15.360000
# 75%      6.000000    1.034000   22.969999    3.730000    3.640000   15.840000
# max      9.000000    4.372000   24.559999    4.250000    4.112000   17.299999
#
#           SPORTHR      READHR      COMPHR     STUDYHR        TVHR   DIOPTERHR  \
# count  618.000000  618.000000  618.000000  618.000000  618.000000  618.000000
# mean    11.953074    2.796117    2.105178    1.490291    8.948220   26.017799
# ...

# %%
# 2 Remove "MYOPIC" column from the dataset
df = df.drop('MYOPIC', axis=1)
# Save cleaned dataframe as new csv file for future analysis
file_path = Path('cleaned_myopia.csv')
df.to_csv(file_path, index=False)

# %%
# 3 Standardize your dataset so that columns that contain larger values do not influence the outcome more than columns with smaller values:

# Create a scaler to standardize data
scaler = StandardScaler()

# Train the scaler with the data
X_scaled = scaler.fit_transform(df)

# %%
# There are 14 dimensions (features/columns) in Myopia Datasets 
X_scaled[0]
# Out:
# array([-0.42021911, -1.3639169 , -0.89286146,  0.48378402, -0.28144315,
#        -1.0197916 ,  4.1506609 ,  1.69744958, -0.68931054, -0.67299591,
#         0.18405806,  0.49830393,  0.98713773,  1.0032415 ])

# %% [markdown]
# # Part 2: Apply Dimensionality Reduction

# %%
# 1 Perform dimensionality reduction with PCA. How did the number of the features change?
 # Initialize PCA model preserving 90% of explained variance in dimensionality reduction
pca = PCA(n_components=0.9)

# Get principal components for the X_train_scaled
myopia_pca = pca.fit_transform(X_scaled)

# Get explained variance ratio
pca.explained_variance_ratio_.sum()
# Out:
# 0.9187361702915188

# %%
# Get shape of features after reduction
myopia_pca.shape
# Out:
# (618, 10)

# %%
# 2 Further reduce the dataset dimensions with t-SNE and visually inspect the results
# To do this, run t-SNE on the principal components, which is the output of the PCA transformation
# Initialize the t-SNE model
tsne = TSNE(learning_rate=250, n_components=3, perplexity=50, verbose=1, n_iter=2500)
# Reduce dimensions
tsne_features = tsne.fit_transform(myopia_pca)
# Out:
# /Users/antara/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 618 samples in 0.054s...
# [t-SNE] Computed neighbors for 618 samples in 0.040s...
# [t-SNE] Computed conditional probabilities for sample 618 / 618
# [t-SNE] Mean sigma: 1.438866
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 101.138763
# [t-SNE] KL divergence after 2500 iterations: 1.945756

# %%
# Get shape of features after reduction
tsne_features.shape
# Out:
# (618, 3)

# %%
# 3 Create a scatter plot of the t-SNE output. Are there distinct clusters?
plt.scatter(tsne_features[:,0],tsne_features[:,1],c=labels)

# %% [markdown]
# # Part 3: Perform a Cluster Analysis with K-means

# %%
# 1 Create an elbow plot to identify the best number of clusters. Make sure to do the following:
# Use a for loop to determine the inertia for each k between 1 through 10.
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(myopia_pca)
    inertia.append(km.inertia_)

# 2 If possible, determine where the elbow of the plot is, and at which value of k it appears.
# Create the Elbow Curve using hvPlot
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.head()
# Out:
#    k      inertia
# 0  1  7948.905345
# 1  2  6794.415695
# 2  3  6031.097742
# 3  4  5662.587617
# 4  5  5376.410589

# %%
# Plot the elbow curve to find best candidate(s) for k
plt.plot(df_elbow['k'], df_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for Myopia')
plt.show()

# %%
len(pca.components_)
# Out:
# 10

# %%
# Create a DataFrame from the PCA transformed data for K-Means modelling and plotting
columns=[]
for i in range(len(pca.components_)):
    columns.append(i+1)
pca_df = pd.DataFrame(myopia_pca, columns=columns)
pca_df['class']= km.labels_
pca_df.head()
# Out:
#           1         2         3         4         5         6         7  \
# 0  0.535503  1.145004 -1.385019  0.116006 -3.226691 -1.928459 -1.958892
# 1 -0.624706 -1.575786 -0.794253  1.156287  0.292256  0.349060 -0.455206
# 2 -0.933479 -0.717076  0.820150 -1.547638  0.173941  0.272783  0.025821
# 3  0.106354  1.192475 -0.024441  1.507469 -2.356836 -0.023139  0.236418
# 4 -0.388503 -2.839655 -0.229767 -0.622510  0.271458 -0.928956  0.537900
#
#           8         9        10  class
# 0 -1.922997  0.026753  0.178144      6
# 1  0.285332  0.689683 -0.557031      2
# 2 -0.030817 -0.431499  0.013336      8
# 3 -1.717109 -1.230785 -0.703400      6
# 4 -1.301787  0.279007  0.631183      2

# %%
# Initialize K-Means model with n_clusters 3
model = KMeans(n_clusters=3, random_state=0)

# Train the model
model.fit(pca_df)

# Predict clusters
predictions = model.predict(pca_df)

# Add predicted clusters (labels) to DataFrame
pca_df['class'] = model.labels_

# Plot the Clusters
plt.scatter(x=pca_df[1], y=pca_df[2], c=pca_df['class'])
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('Myopia clusters')
plt.show()
# Out:
# /Users/antara/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /Users/antara/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %% [markdown]
# # Part 4: Make a Recommendation

# %% [markdown]
# # Myopia Clusters Findings

# %% [markdown]
# After Preparing the Data, Applying Dimensionality Reduction using PCA and reducing this further with t-SNE, I performed a Cluster Analysis with K-Means model. I found that:
#
# - The optimal number of clusters is 3
#
# - T-SNE was not helpful in finding clusters, and although there were some some differences after adjusting perplexity, this was perchance due to random noise
#
# - There are some patterns after performing the K-Means clustering, but the dataset is too small to make an accurate prediction or for further splitting and training of data
#
# Based on my findings, my recommendation is that the patients cannot be clustered. My recommendation is to obtain a larger dataset and to split the data into Test and Training to test the above models and others to be able to make more accurate predictions and clustering.
